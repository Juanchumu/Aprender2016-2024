# %%
# Import librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#markdown de que tratan las columnas
#hacer un grafico de una pregunta interesante (grupo de columnas) 
#primeras 15 patrick
#siguient bruno 
#34 a final juan
#https://docs.google.com/document/d/1xeXGwWcrq0DfJiaZdMEY90f4sume7BjmDSZ1k1nbNno/edit?usp=sharing
#https://data.educacion.gob.ar/aprender-respuestas-estudiante

# %%
ruta_archivo = "../data/raw/2024 Base APRENDER - Censal - Secundaria 5-6 año - Agregada - Desempeños de Lengua(in).csv"

# %%
# cargar la versión CSV:
#data = pd.read_csv(ruta_archivo, sep=';', encoding='utf-8')
data = pd.read_csv(ruta_archivo, sep=';', encoding="latin-1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1228 entries, 0 to 1227
# Columns: 1035 entries, jurisdiccion to Nivel_Ed_Persona_Resp_Terciario_universitario_posgrado_completo
# dtypes: object(1035)
# memory usage: 9.7+ MB

# %% [markdown]
# # Dataset
#
#
#
# * las columnas 12345 tratan de edad:

# %%
from pandas.api.types import is_numeric_dtype

def analizar_dataframe(df):
    for col in df.columns:
        print(f"\nColumna: {col}")
        tipo = df[col].dtype

        if is_numeric_dtype(tipo):
            print("Tipo: float")
            print(f"  Media: {df[col].mean()}")
            print(f"  Moda: {df[col].mode().iloc[0] if not df[col].mode().empty else 'Sin moda'}")
            print(f"  Mínimo: {df[col].min()}")
            print(f"  Máximo: {df[col].max()}")

        elif pd.api.types.is_object_dtype(tipo):
            print("Tipo: objeto")
            num_categorias = df[col].nunique()
            if num_categorias > 20:
                print(f"  Más de 20 categorías ({num_categorias}), no se listan.")
            else:
                print(f"  Categorías más frecuentes:")
                print(f"  {df[col].value_counts().head(5)}")
        else:
            print(f"Tipo no explorado: {tipo}")
        print("\n")

# %%
analizar_dataframe(data)
# Out:
# Columna: jurisdiccion
# Tipo: objeto
#   Más de 20 categorías (24), no se listan.
#
#
#
# Columna: departamento
# Tipo: objeto
#   Más de 20 categorías (440), no se listan.
#
#
#
# Columna: sector
# Tipo: objeto
#   Categorías más frecuentes:
#   sector
# Estatal    894
# Privado    334
# Name: count, dtype: int64
#
#
#
# Columna: ambito
# Tipo: objeto
#   Categorías más frecuentes:
#   ambito
# Urbano    756
# Rural     472
# Name: count, dtype: int64
#
#
#
# Columna: ap01_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap01_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap01_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap01_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap01_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap01_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap01_Enero
# Tipo: objeto
#   Más de 20 categorías (1152), no se listan.
#
#
#
# Columna: ap01_Febrero
# Tipo: objeto
#   Más de 20 categorías (1143), no se listan.
#
#
#
# Columna: ap01_Marzo
# Tipo: objeto
#   Más de 20 categorías (1157), no se listan.
#
#
#
# Columna: ap01_Abril
# Tipo: objeto
#   Más de 20 categorías (1156), no se listan.
#
#
#
# Columna: ap01_Mayo
# Tipo: objeto
#   Más de 20 categorías (1146), no se listan.
#
#
#
# Columna: ap01_Junio
# Tipo: objeto
#   Más de 20 categorías (1154), no se listan.
#
#
#
# Columna: ap01_Julio
# Tipo: objeto
#   Más de 20 categorías (1144), no se listan.
#
#
#
# Columna: ap01_Agosto
# Tipo: objeto
#   Más de 20 categorías (1148), no se listan.
#
#
#
# Columna: ap01_Septiembre
# Tipo: objeto
#   Más de 20 categorías (1149), no se listan.
#
#
#
# Columna: ap01_Octubre
# Tipo: objeto
#   Más de 20 categorías (1138), no se listan.
#
#
#
# Columna: ap01_Noviembre
# Tipo: objeto
#   Más de 20 categorías (1136), no se listan.
#
#
#
# Columna: ap01_Diciembre
# Tipo: objeto
#   Más de 20 categorías (1151), no se listan.
#
#
#
# Columna: ap02_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap02_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap02_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap02_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap02_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap02_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap02_Antes_de_2002
# Tipo: objeto
#   Más de 20 categorías (436), no se listan.
#
#
#
# Columna: ap02_2002
# Tipo: objeto
#   Más de 20 categorías (289), no se listan.
#
#
#
# Columna: ap02_2003
# Tipo: objeto
#   Más de 20 categorías (452), no se listan.
#
#
#
# Columna: ap02_2004
# Tipo: objeto
#   Más de 20 categorías (789), no se listan.
#
#
#
# Columna: ap02_2005
# Tipo: objeto
#   Más de 20 categorías (1098), no se listan.
#
#
#
# Columna: ap02_2006
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap02_2007
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap02_2008
# Tipo: objeto
#   Más de 20 categorías (244), no se listan.
#
#
#
# Columna: ap02_Después_de_2008
# Tipo: objeto
#   Más de 20 categorías (192), no se listan.
#
#
#
# Columna: ap03_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap03_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap03_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap03_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap03_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap03_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap03_Masculino
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap03_Femenino
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap03_X
# Tipo: objeto
#   Más de 20 categorías (734), no se listan.
#
#
#
# Columna: ap04_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap04_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap04_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap04_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap04_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap04_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap04_Argentina
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap04_Bolivia
# Tipo: objeto
#   Más de 20 categorías (470), no se listan.
#
#
#
# Columna: ap04_Brasil
# Tipo: objeto
#   Más de 20 categorías (364), no se listan.
#
#
#
# Columna: ap04_Chile
# Tipo: objeto
#   Más de 20 categorías (178), no se listan.
#
#
#
# Columna: ap04_Colombia
# Tipo: objeto
#   Más de 20 categorías (202), no se listan.
#
#
#
# Columna: ap04_Ecuador
# Tipo: objeto
#   Más de 20 categorías (90), no se listan.
#
#
#
# Columna: ap04_Paraguay
# Tipo: objeto
#   Más de 20 categorías (314), no se listan.
#
#
#
# Columna: ap04_Perú
# Tipo: objeto
#   Más de 20 categorías (269), no se listan.
#
#
#
# Columna: ap04_Uruguay
# Tipo: objeto
#   Más de 20 categorías (134), no se listan.
#
#
#
# Columna: ap04_Venezuela
# Tipo: objeto
#   Más de 20 categorías (221), no se listan.
#
#
#
# Columna: ap04_Otro_país_de_América
# Tipo: objeto
#   Más de 20 categorías (255), no se listan.
#
#
#
# Columna: ap04_En_un_país_de_Europa
# Tipo: objeto
#   Más de 20 categorías (522), no se listan.
#
#
#
# Columna: ap04_En_un_país_de_Asia
# Tipo: objeto
#   Más de 20 categorías (215), no se listan.
#
#
#
# Columna: ap04_En_un_país_de_Oceanía
# Tipo: objeto
#   Más de 20 categorías (208), no se listan.
#
#
#
# Columna: ap04_En_un_país_de_África
# Tipo: objeto
#   Más de 20 categorías (342), no se listan.
#
#
#
# Columna: ap05a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05a_En_Argentina
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap05a_En_otro_país_que_no_es_Argentina
# Tipo: objeto
#   Más de 20 categorías (898), no se listan.
#
#
#
# Columna: ap05b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05b_En_Argentina
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap05b_En_otro_país_que_no_es_Argentina
# Tipo: objeto
#   Más de 20 categorías (936), no se listan.
#
#
#
# Columna: ap05c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap05c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap05c_En_Argentina
# Tipo: objeto
#   Más de 20 categorías (1206), no se listan.
#
#
#
# Columna: ap05c_En_otro_país_que_no_es_Argentina
# Tipo: objeto
#   Más de 20 categorías (638), no se listan.
#
#
#
# Columna: ap06_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap06_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap06_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap06_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap06_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap06_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap06_Sí
# Tipo: objeto
#   Más de 20 categorías (1163), no se listan.
#
#
#
# Columna: ap06_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap07_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap07_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap07_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap07_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap07_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap07_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap07_Sí
# Tipo: objeto
#   Más de 20 categorías (998), no se listan.
#
#
#
# Columna: ap07_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap10_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap10_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap10_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap10_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap10_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap10_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap10_En_mi_casa_o_departamento
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap10_En_un_hogar_de_jóvenes_o_similar
# Tipo: objeto
#   Más de 20 categorías (378), no se listan.
#
#
#
# Columna: ap10_En_una_pensión_casa_hogar_hotel_etc
# Tipo: objeto
#   Más de 20 categorías (557), no se listan.
#
#
#
# Columna: ap10_En_una_casa_club_o_pensión_deportiva
# Tipo: objeto
#   Más de 20 categorías (369), no se listan.
#
#
#
# Columna: ap10_En_la_escuela
# Tipo: objeto
#   Más de 20 categorías (621), no se listan.
#
#
#
# Columna: ap10_En_otro_lugar
# Tipo: objeto
#   Más de 20 categorías (777), no se listan.
#
#
#
# Columna: ap11_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap11_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap11_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap11_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap11_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap11_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap11_1
# Tipo: objeto
#   Más de 20 categorías (975), no se listan.
#
#
#
# Columna: ap11_2
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap11_3
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap11_4
# Tipo: objeto
#   Más de 20 categorías (1180), no se listan.
#
#
#
# Columna: ap11_5
# Tipo: objeto
#   Más de 20 categorías (1071), no se listan.
#
#
#
# Columna: ap11_6
# Tipo: objeto
#   Más de 20 categorías (878), no se listan.
#
#
#
# Columna: ap11_7
# Tipo: objeto
#   Más de 20 categorías (685), no se listan.
#
#
#
# Columna: ap11_8
# Tipo: objeto
#   Más de 20 categorías (503), no se listan.
#
#
#
# Columna: ap11_9
# Tipo: objeto
#   Más de 20 categorías (352), no se listan.
#
#
#
# Columna: ap11_10_o_más
# Tipo: objeto
#   Más de 20 categorías (647), no se listan.
#
#
#
# Columna: ap12_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap12_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap12_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap12_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap12_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap12_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap12_Vivo_solo
# Tipo: objeto
#   Más de 20 categorías (673), no se listan.
#
#
#
# Columna: ap12_2
# Tipo: objeto
#   Más de 20 categorías (1129), no se listan.
#
#
#
# Columna: ap12_3
# Tipo: objeto
#   Más de 20 categorías (1205), no se listan.
#
#
#
# Columna: ap12_4
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap12_5
# Tipo: objeto
#   Más de 20 categorías (1205), no se listan.
#
#
#
# Columna: ap12_6
# Tipo: objeto
#   Más de 20 categorías (1142), no se listan.
#
#
#
# Columna: ap12_7
# Tipo: objeto
#   Más de 20 categorías (996), no se listan.
#
#
#
# Columna: ap12_8
# Tipo: objeto
#   Más de 20 categorías (838), no se listan.
#
#
#
# Columna: ap12_9
# Tipo: objeto
#   Más de 20 categorías (638), no se listan.
#
#
#
# Columna: ap12_10_o_más
# Tipo: objeto
#   Más de 20 categorías (787), no se listan.
#
#
#
# Columna: ap13a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13a_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1181), no se listan.
#
#
#
# Columna: ap13a_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap13b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13b_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap13b_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap13c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13c_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap13c_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1165), no se listan.
#
#
#
# Columna: ap13d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13d_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap13d_Selecciona
# Tipo: objeto
#   Más de 20 categorías (908), no se listan.
#
#
#
# Columna: ap13e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13e_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap13e_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap13f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13f_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap13f_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1018), no se listan.
#
#
#
# Columna: ap13g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13g_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap13g_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1137), no se listan.
#
#
#
# Columna: ap13h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13h_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap13h_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1014), no se listan.
#
#
#
# Columna: ap13i_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13i_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13i_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13i_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13i_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap13i_Selecciona
# Tipo: objeto
#   Más de 20 categorías (629), no se listan.
#
#
#
# Columna: ap13j_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13j_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13j_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap13j_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap13j_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap13j_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1039), no se listan.
#
#
#
# Columna: ap14_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap14_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap14_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap14_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap14_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap14_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap14_Sí
# Tipo: objeto
#   Más de 20 categorías (938), no se listan.
#
#
#
# Columna: ap14_No
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap15_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap15_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap15_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap15_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap15_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap15_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap15_Sí
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap15_No
# Tipo: objeto
#   Más de 20 categorías (1181), no se listan.
#
#
#
# Columna: ap16a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16a_Sí
# Tipo: objeto
#   Más de 20 categorías (1223), no se listan.
#
#
#
# Columna: ap16a_No
# Tipo: objeto
#   Más de 20 categorías (1208), no se listan.
#
#
#
# Columna: ap16b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16b_Sí
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap16b_No
# Tipo: objeto
#   Más de 20 categorías (1093), no se listan.
#
#
#
# Columna: ap16c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16c_Sí
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap16c_No
# Tipo: objeto
#   Más de 20 categorías (1039), no se listan.
#
#
#
# Columna: ap16d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16d_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16d_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16d_Sí
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap16d_No
# Tipo: objeto
#   Más de 20 categorías (974), no se listan.
#
#
#
# Columna: ap16e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16e_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16e_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16e_Sí
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap16e_No
# Tipo: objeto
#   Más de 20 categorías (991), no se listan.
#
#
#
# Columna: ap16f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16f_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16f_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16f_Sí
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap16f_No
# Tipo: objeto
#   Más de 20 categorías (910), no se listan.
#
#
#
# Columna: ap16g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16g_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16g_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16g_Sí
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap16g_No
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap16h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16h_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16h_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16h_Sí
# Tipo: objeto
#   Más de 20 categorías (1203), no se listan.
#
#
#
# Columna: ap16h_No
# Tipo: objeto
#   Más de 20 categorías (1223), no se listan.
#
#
#
# Columna: ap16i_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16i_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16i_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16i_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16i_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16i_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16i_Sí
# Tipo: objeto
#   Más de 20 categorías (1183), no se listan.
#
#
#
# Columna: ap16i_No
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap16j_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16j_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16j_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16j_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16j_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16j_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16j_Sí
# Tipo: objeto
#   Más de 20 categorías (1209), no se listan.
#
#
#
# Columna: ap16j_No
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap16k_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16k_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16k_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16k_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16k_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16k_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16k_Sí
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap16k_No
# Tipo: objeto
#   Más de 20 categorías (1046), no se listan.
#
#
#
# Columna: ap16l_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16l_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16l_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16l_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16l_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap16l_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap16l_Sí
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap16l_No
# Tipo: objeto
#   Más de 20 categorías (1019), no se listan.
#
#
#
# Columna: ap17_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap17_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap17_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap17_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap17_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap17_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap17_1
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap17_2
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap17_3_o_más
# Tipo: objeto
#   Más de 20 categorías (1030), no se listan.
#
#
#
# Columna: ap18_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap18_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap18_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap18_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap18_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap18_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap18_No_tienen
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap18_Sí_tienen_1
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap18_Sí_tienen_2_o_más
# Tipo: objeto
#   Más de 20 categorías (1205), no se listan.
#
#
#
# Columna: ap19_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap19_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap19_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap19_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap19_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap19_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap19_No_hay_libros_en_formato_papel
# Tipo: objeto
#   Más de 20 categorías (1174), no se listan.
#
#
#
# Columna: ap19_De_1_a_5_libros
# Tipo: objeto
#   Más de 20 categorías (1213), no se listan.
#
#
#
# Columna: ap19_De_6_a_20_libros
# Tipo: objeto
#   Más de 20 categorías (1213), no se listan.
#
#
#
# Columna: ap19_De_21_a_50_libros
# Tipo: objeto
#   Más de 20 categorías (1190), no se listan.
#
#
#
# Columna: ap19_De_51_a_100_libros
# Tipo: objeto
#   Más de 20 categorías (1132), no se listan.
#
#
#
# Columna: ap19_Más_de_100_libros
# Tipo: objeto
#   Más de 20 categorías (1088), no se listan.
#
#
#
# Columna: ap20a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20a_Sí
# Tipo: objeto
#   Más de 20 categorías (1213), no se listan.
#
#
#
# Columna: ap20a_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap20b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20b_Sí
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap20b_No
# Tipo: objeto
#   Más de 20 categorías (1223), no se listan.
#
#
#
# Columna: ap20c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20c_Sí
# Tipo: objeto
#   Más de 20 categorías (1221), no se listan.
#
#
#
# Columna: ap20c_No
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap20d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20d_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20d_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20d_Sí
# Tipo: objeto
#   Más de 20 categorías (1057), no se listan.
#
#
#
# Columna: ap20d_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap20e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20e_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20e_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20e_Sí
# Tipo: objeto
#   Más de 20 categorías (1205), no se listan.
#
#
#
# Columna: ap20e_No
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap20f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20f_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20f_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20f_Sí
# Tipo: objeto
#   Más de 20 categorías (1219), no se listan.
#
#
#
# Columna: ap20f_No
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap20g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20g_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20g_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20g_Sí
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap20g_No
# Tipo: objeto
#   Más de 20 categorías (1193), no se listan.
#
#
#
# Columna: ap20h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20h_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20h_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20h_Sí
# Tipo: objeto
#   Más de 20 categorías (1221), no se listan.
#
#
#
# Columna: ap20h_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap20i_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20i_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20i_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20i_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20i_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20i_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20i_Sí
# Tipo: objeto
#   Más de 20 categorías (1190), no se listan.
#
#
#
# Columna: ap20i_No
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap20j_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20j_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20j_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20j_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20j_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20j_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20j_Sí
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap20j_No
# Tipo: objeto
#   Más de 20 categorías (1219), no se listan.
#
#
#
# Columna: ap20k_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20k_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20k_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20k_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20k_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20k_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20k_Sí
# Tipo: objeto
#   Más de 20 categorías (1210), no se listan.
#
#
#
# Columna: ap20k_No
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap20l_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20l_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20l_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20l_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20l_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20l_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20l_Sí
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap20l_No
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap20m_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20m_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20m_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20m_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20m_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap20m_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap20m_Sí
# Tipo: objeto
#   Más de 20 categorías (1152), no se listan.
#
#
#
# Columna: ap20m_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap21a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21a_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1137), no se listan.
#
#
#
# Columna: ap21a_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap21a_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1212), no se listan.
#
#
#
# Columna: ap21a_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1120), no se listan.
#
#
#
# Columna: ap21a_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1067), no se listan.
#
#
#
# Columna: ap21b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21b_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap21b_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1200), no se listan.
#
#
#
# Columna: ap21b_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1132), no se listan.
#
#
#
# Columna: ap21b_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (996), no se listan.
#
#
#
# Columna: ap21b_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1014), no se listan.
#
#
#
# Columna: ap21c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21c_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap21c_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1214), no se listan.
#
#
#
# Columna: ap21c_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1115), no se listan.
#
#
#
# Columna: ap21c_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (867), no se listan.
#
#
#
# Columna: ap21c_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (843), no se listan.
#
#
#
# Columna: ap21d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21d_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21d_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21d_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1223), no se listan.
#
#
#
# Columna: ap21d_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap21d_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1164), no se listan.
#
#
#
# Columna: ap21d_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (979), no se listan.
#
#
#
# Columna: ap21d_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (881), no se listan.
#
#
#
# Columna: ap21e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21e_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap21e_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap21e_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap21e_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1205), no se listan.
#
#
#
# Columna: ap21e_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1094), no se listan.
#
#
#
# Columna: ap21e_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (927), no se listan.
#
#
#
# Columna: ap21e_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (970), no se listan.
#
#
#
# Columna: ap22a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22a_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap22a_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1196), no se listan.
#
#
#
# Columna: ap22a_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1162), no se listan.
#
#
#
# Columna: ap22a_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1041), no se listan.
#
#
#
# Columna: ap22a_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1051), no se listan.
#
#
#
# Columna: ap22b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22b_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap22b_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1140), no se listan.
#
#
#
# Columna: ap22b_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1104), no se listan.
#
#
#
# Columna: ap22b_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (959), no se listan.
#
#
#
# Columna: ap22b_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (959), no se listan.
#
#
#
# Columna: ap22c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap22c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap22c_No_hice_estas_actividades
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap22c_Menos_de_5_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1201), no se listan.
#
#
#
# Columna: ap22c_Entre_5_y_10_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1170), no se listan.
#
#
#
# Columna: ap22c_Entre_11_y_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1046), no se listan.
#
#
#
# Columna: ap22c_Más_de_20_horas_en_la_semana
# Tipo: objeto
#   Más de 20 categorías (1025), no se listan.
#
#
#
# Columna: ap23_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap23_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap23_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap23_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap23_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap23_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap23_Sí_recibí_dinero_por_todas_ellas
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap23_Sí_recibí_dinero_por_alguna_de_ellas
# Tipo: objeto
#   Más de 20 categorías (1203), no se listan.
#
#
#
# Columna: ap23_No_no_recibí_dinero
# Tipo: objeto
#   Más de 20 categorías (1188), no se listan.
#
#
#
# Columna: ap24_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap24_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap24_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap24_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap24_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap24_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap24_Sí_desde_sala_de_3_o_antes
# Tipo: objeto
#   Más de 20 categorías (1217), no se listan.
#
#
#
# Columna: ap24_Sí_desde_sala_de_4
# Tipo: objeto
#   Más de 20 categorías (1197), no se listan.
#
#
#
# Columna: ap24_Sí_desde_sala_de_5
# Tipo: objeto
#   Más de 20 categorías (1132), no se listan.
#
#
#
# Columna: ap24_No_no_fui_al_jardín
# Tipo: objeto
#   Más de 20 categorías (784), no se listan.
#
#
#
# Columna: ap25a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25a_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25a_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25a_No
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap25a_Sí_una_vez
# Tipo: objeto
#   Más de 20 categorías (1039), no se listan.
#
#
#
# Columna: ap25a_Sí_dos_o_más_veces
# Tipo: objeto
#   Más de 20 categorías (622), no se listan.
#
#
#
# Columna: ap25b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25b_No
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap25b_Sí_una_vez
# Tipo: objeto
#   Más de 20 categorías (1036), no se listan.
#
#
#
# Columna: ap25b_Sí_dos_o_más_veces
# Tipo: objeto
#   Más de 20 categorías (729), no se listan.
#
#
#
# Columna: ap25c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap25c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap25c_No
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap25c_Sí_una_vez
# Tipo: objeto
#   Más de 20 categorías (994), no se listan.
#
#
#
# Columna: ap25c_Sí_dos_o_más_veces
# Tipo: objeto
#   Más de 20 categorías (630), no se listan.
#
#
#
# Columna: ap26_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap26_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap26_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap26_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap26_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap26_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap26_Sí
# Tipo: objeto
#   Más de 20 categorías (1209), no se listan.
#
#
#
# Columna: ap26_No
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap27_Ninguna_falta
# Tipo: objeto
#   Más de 20 categorías (992), no se listan.
#
#
#
# Columna: ap27_Menos_de_5_faltas
# Tipo: objeto
#   Más de 20 categorías (1180), no se listan.
#
#
#
# Columna: ap27_De_5_a_14_faltas
# Tipo: objeto
#   Más de 20 categorías (1216), no se listan.
#
#
#
# Columna: ap27_De_15_a_19_faltas
# Tipo: objeto
#   Más de 20 categorías (1189), no se listan.
#
#
#
# Columna: ap27_De_20_a_29_faltas
# Tipo: objeto
#   Más de 20 categorías (1129), no se listan.
#
#
#
# Columna: ap27_30_o_más_faltas
# Tipo: objeto
#   Más de 20 categorías (1047), no se listan.
#
#
#
# Columna: ap28a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28a_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap28a_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap28b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28b_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap28b_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1183), no se listan.
#
#
#
# Columna: ap28c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28c_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap28c_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1207), no se listan.
#
#
#
# Columna: ap28d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28d_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap28d_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap28e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28e_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap28e_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1128), no se listan.
#
#
#
# Columna: ap28f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28f_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap28f_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1133), no se listan.
#
#
#
# Columna: ap28g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28g_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap28g_Selecciona
# Tipo: objeto
#   Más de 20 categorías (646), no se listan.
#
#
#
# Columna: ap28h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28h_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap28h_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1143), no se listan.
#
#
#
# Columna: ap28i_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28i_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28i_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28i_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28i_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap28i_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1142), no se listan.
#
#
#
# Columna: ap28j_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28j_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28j_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28j_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28j_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap28j_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1147), no se listan.
#
#
#
# Columna: ap28k_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28k_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap28k_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap28k_No_disponible
#     1228
# ...
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42b_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42b_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42b_Sí
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap42b_No
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap42c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42c_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42c_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42c_Sí
# Tipo: objeto
#   Más de 20 categorías (1223), no se listan.
#
#
#
# Columna: ap42c_No
# Tipo: objeto
#   Más de 20 categorías (1219), no se listan.
#
#
#
# Columna: ap42d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42d_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42d_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42d_Sí
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap42d_No
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap42e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42e_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42e_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42e_Sí
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap42e_No
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap42f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42f_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42f_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42f_Sí
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap42f_No
# Tipo: objeto
#   Más de 20 categorías (1224), no se listan.
#
#
#
# Columna: ap42g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42g_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42g_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42g_Sí
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap42g_No
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ap42h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42h_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap42h_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap42h_Sí
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap42h_No
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap43a_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43a_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43a_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43a_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43a_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1220), no se listan.
#
#
#
# Columna: ap43a_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ap43b_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43b_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43b_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43b_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43b_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1202), no se listan.
#
#
#
# Columna: ap43b_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap43c_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43c_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43c_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43c_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43c_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap43c_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1204), no se listan.
#
#
#
# Columna: ap43d_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43d_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43d_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43d_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43d_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap43d_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1216), no se listan.
#
#
#
# Columna: ap43e_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43e_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43e_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43e_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43e_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap43e_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1087), no se listan.
#
#
#
# Columna: ap43f_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43f_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43f_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43f_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43f_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap43f_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1051), no se listan.
#
#
#
# Columna: ap43g_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43g_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43g_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43g_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43g_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap43g_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1123), no se listan.
#
#
#
# Columna: ap43h_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43h_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43h_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43h_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43h_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: ap43h_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1210), no se listan.
#
#
#
# Columna: ap43i_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43i_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43i_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43i_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43i_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1225), no se listan.
#
#
#
# Columna: ap43i_Selecciona
# Tipo: objeto
#   Más de 20 categorías (1215), no se listan.
#
#
#
# Columna: ap43j_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43j_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43j_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap43j_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap43j_No_selecciona
# Tipo: objeto
#   Más de 20 categorías (1227), no se listan.
#
#
#
# Columna: ap43j_Selecciona
# Tipo: objeto
#   Más de 20 categorías (990), no se listan.
#
#
#
# Columna: ap44_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   ap44_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap44_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   ap44_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap44_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   ap44_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: ap44_Sí_me_apoya_y_me_ayuda_a_tomar_decisiones
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: ap44_Sí_me_apoya_pero_no_me_ayuda_a_tomar_decisiones
# Tipo: objeto
#   Más de 20 categorías (1173), no se listan.
#
#
#
# Columna: ap44_No_me_apoya_pero_me_ayuda_a_tomar_decisiones
# Tipo: objeto
#   Más de 20 categorías (976), no se listan.
#
#
#
# Columna: ap44_No_me_apoya_ni_me_ayuda_a_tomar_decisiones
# Tipo: objeto
#   Más de 20 categorías (949), no se listan.
#
#
#
# Columna: ldesemp_Por_debajo_del_nivel_básico
# Tipo: objeto
#   Más de 20 categorías (1197), no se listan.
#
#
#
# Columna: ldesemp_Básico
# Tipo: objeto
#   Más de 20 categorías (1218), no se listan.
#
#
#
# Columna: ldesemp_Satisfactorio
# Tipo: objeto
#   Más de 20 categorías (1222), no se listan.
#
#
#
# Columna: ldesemp_Avanzado
# Tipo: objeto
#   Más de 20 categorías (960), no se listan.
#
#
#
# Columna: edadA_junio2024_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   edadA_junio2024_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: edadA_junio2024_Menos_de_15_años
# Tipo: objeto
#   Más de 20 categorías (192), no se listan.
#
#
#
# Columna: edadA_junio2024_15_años
# Tipo: objeto
#   Más de 20 categorías (70), no se listan.
#
#
#
# Columna: edadA_junio2024_16_años
# Tipo: objeto
#   Más de 20 categorías (637), no se listan.
#
#
#
# Columna: edadA_junio2024_17_años
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: edadA_junio2024_18_años
# Tipo: objeto
#   Más de 20 categorías (1161), no se listan.
#
#
#
# Columna: edadA_junio2024_19_años
# Tipo: objeto
#   Más de 20 categorías (932), no se listan.
#
#
#
# Columna: edadA_junio2024_20_años
# Tipo: objeto
#   Más de 20 categorías (594), no se listan.
#
#
#
# Columna: edadA_junio2024_21_años
# Tipo: objeto
#   Más de 20 categorías (348), no se listan.
#
#
#
# Columna: edadA_junio2024_22_años
# Tipo: objeto
#   Más de 20 categorías (171), no se listan.
#
#
#
# Columna: edadA_junio2024_Más_de_22_años
# Tipo: objeto
#   Más de 20 categorías (436), no se listan.
#
#
#
# Columna: sobreedad_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   sobreedad_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: sobreedad_Menores_de_17_años
# Tipo: objeto
#   Más de 20 categorías (666), no se listan.
#
#
#
# Columna: sobreedad_Edad_teórica_para_el_año_17_años_al_30_de_junio
# Tipo: objeto
#   Más de 20 categorías (1228), no se listan.
#
#
#
# Columna: sobreedad_1_año_de_sobreedad_18_años_al_30_de_junio
# Tipo: objeto
#   Más de 20 categorías (1161), no se listan.
#
#
#
# Columna: sobreedad_2_años_de_sobreedad_19_años_al_30_de_junio
# Tipo: objeto
#   Más de 20 categorías (932), no se listan.
#
#
#
# Columna: sobreedad_3_años_o_más_de_sobreedad_20_años_mas_30Jun
# Tipo: objeto
#   Más de 20 categorías (763), no se listan.
#
#
#
# Columna: migracion_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   migracion_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: migracion_Configuración_familiar_migrante
# Tipo: objeto
#   Más de 20 categorías (1040), no se listan.
#
#
#
# Columna: migracion_Configuración_familiar_no_migrante
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: repitencia__Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   repitencia__Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: repitencia_Repitió_1_vez
# Tipo: objeto
#   Más de 20 categorías (1151), no se listan.
#
#
#
# Columna: repitencia_Repitió_2_veces_o_más
# Tipo: objeto
#   Más de 20 categorías (893), no se listan.
#
#
#
# Columna: repitencia_Nunca_repitió
# Tipo: objeto
#   Más de 20 categorías (1226), no se listan.
#
#
#
# Columna: clima_Bajo
# Tipo: objeto
#   Más de 20 categorías (775), no se listan.
#
#
#
# Columna: clima_Medio
# Tipo: objeto
#   Más de 20 categorías (1012), no se listan.
#
#
#
# Columna: clima_Alto
# Tipo: objeto
#   Más de 20 categorías (692), no se listan.
#
#
#
# Columna: NSE_Quintiles_Q1
# Tipo: objeto
#   Más de 20 categorías (1191), no se listan.
#
#
#
# Columna: NSE_Quintiles_Q2
# Tipo: objeto
#   Más de 20 categorías (1201), no se listan.
#
#
#
# Columna: NSE_Quintiles_Q3
# Tipo: objeto
#   Más de 20 categorías (1207), no se listan.
#
#
#
# Columna: NSE_Quintiles_Q4
# Tipo: objeto
#   Más de 20 categorías (1180), no se listan.
#
#
#
# Columna: NSE_Quintiles_Q5
# Tipo: objeto
#   Más de 20 categorías (1124), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Madre_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Madre_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Madre_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Madre_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Madre_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Madre_No_fue_a_la_escuela
# Tipo: objeto
#   Más de 20 categorías (623), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Primaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (1120), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Primaria_completo
# Tipo: objeto
#   Más de 20 categorías (1161), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Secundaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (1192), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Secundaria_completo
# Tipo: objeto
#   Más de 20 categorías (1217), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Terciario_universitario_posgrado_incompleto
# Tipo: objeto
#   Más de 20 categorías (997), no se listan.
#
#
#
# Columna: Nivel_Ed_Madre_Terciario_universitario_posgrado_completo
# Tipo: objeto
#   Más de 20 categorías (1182), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Padre_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Padre_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Padre_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Padre_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Padre_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Padre_No_fue_a_la_escuela
# Tipo: objeto
#   Más de 20 categorías (846), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Primaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (1195), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Primaria_completo
# Tipo: objeto
#   Más de 20 categorías (1180), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Secundaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (1198), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Secundaria_completo
# Tipo: objeto
#   Más de 20 categorías (1188), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Terciario_universitario_posgrado_incompleto
# Tipo: objeto
#   Más de 20 categorías (935), no se listan.
#
#
#
# Columna: Nivel_Ed_Padre_Terciario_universitario_posgrado_completo
# Tipo: objeto
#   Más de 20 categorías (1133), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Blanco
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Persona_Resp_Blanco
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Persona_Resp_No_disponible
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Persona_Resp_No_disponible
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Multimarca
# Tipo: objeto
#   Categorías más frecuentes:
#   Nivel_Ed_Persona_Resp_Multimarca
#     1228
# Name: count, dtype: int64
#
#
#
# Columna: Nivel_Ed_Persona_Resp_No_fue_a_la_escuela
# Tipo: objeto
#   Más de 20 categorías (603), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Primaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (810), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Primaria_completo
# Tipo: objeto
#   Más de 20 categorías (845), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Secundaria_incompleto
# Tipo: objeto
#   Más de 20 categorías (952), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Secundaria_completo
# Tipo: objeto
#   Más de 20 categorías (1076), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Terciario_universitario_posgrado_incomple
# Tipo: objeto
#   Más de 20 categorías (726), no se listan.
#
#
#
# Columna: Nivel_Ed_Persona_Resp_Terciario_universitario_posgrado_completo
# Tipo: objeto
#   Más de 20 categorías (1031), no se listan.
